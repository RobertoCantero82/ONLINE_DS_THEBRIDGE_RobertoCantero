# %% [markdown]
# ## Ejercicios de Matplotlib

# %% [markdown]
# 1. Importa pyplot, numpy y pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 2. Sabemos que podemos pintar gráficas de dos formas: la figura incluye los ejes o teniendo figura y ejes por separado.
#
# Usando solo una figura, usa numpy para los valores del eje X entre 0 y 5.
#
# Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3 que pase por (0,-5).
#
# Elige la precisión en el eje X que desees.

# %%
x = np.linspace(0,5) # para el eje x generamos un array de 0 a 5

y1 = x * 3 # el primer caso, el eje y tendrá los elementos multiplicados por 3

y2 = (-3 * x) -5 # aquí el eje y 

plt.subplot(1, 2, 1) # habrá una fila y dos columnas y este será el primer gráfico
plt.plot(x, y1) # creo el gráfico con x e y1

plt.subplot(1, 2, 2) # habrá una fila y dos columnas y este será el segundo gráfico
plt.plot(x,y2); # creo el gráfico con x e y2

# %% [markdown]
# 3. Fija el eje X entre 0 y 5 y el eje Y entre -15 y 15

# %%
x = np.linspace(0,5)

y1 = x * 3
y2 = -3 * x - 5

plt.subplot(1, 2, 1)
plt.plot(x, y1)
plt.xlim(0, 5) # añado el límite de x (entre 0 y 5)
plt.ylim(-15, 15) # añado el límite de y (entre -15 y 15)

plt.subplot(1, 2, 2)
plt.plot(x, y2)
plt.xlim(0, 5) # añado el límite de x (entre 0 y 5)
plt.ylim(-15, 15); # añado el límite de y (entre -15 y 15)

# %% [markdown]
# 4. Llama al eje X "eje X", al eje Y "eje Y" y pon de títulos "recta sube" y "recta baja". Muestra dos etiquetas de ejeX pero solo una de eje Y.

# %%
x = np.linspace(0,5)

y1 = x * 3
y2 = -3 * x - 5

plt.subplot(1, 2, 1)
plt.plot(x, y1)
plt.xlim(0, 5)
plt.ylim(-15, 15)
plt.xlabel("eje X")      # Etiqueta eje X
plt.ylabel("eje Y")      # Etiqueta eje Y 
plt.title("recta sube")  # Título

plt.subplot(1, 2, 2)
plt.plot(x, y2)
plt.xlim(0, 5)
plt.ylim(-15, 15)
plt.xlabel("eje X")      # Etiqueta eje X
plt.title("recta baja");  # Título

# %% [markdown]
# 5. Usando una figura Y EJES POR SEPARADO, usa numpy para los valores del eje X entre 0 y 5. Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3 que pase por (0,-5). Elige la precisión en el eje X que desees.

# %%
x = np.linspace(0, 5)

y1 = 3 * x
y2 = -3 * x - 5

fig, (ax_izq, ax_dch) = plt.subplots(1, 2, figsize=(10, 4)) # creo una figura con dos subplots en horizontal

ax_izq.plot(x, y1)
ax_izq.set_xlim(0, 5)
ax_izq.set_ylim(-15, 15)

ax_dch.plot(x, y2)
ax_dch.set_xlim(0, 5)
ax_dch.set_ylim(-15, 15)
# Out:
# (-15.0, 15.0)

# %% [markdown]
# ### Otra manera de hacerlo:

# %%
fig, ax = plt.subplots(1, 2)

ax[0].plot(x,y1)
ax[0].set_xlim(0,5)
ax[0].set_ylim(-15,15)
ax[0].set_title("recta sube")
ax[0].set_xlabel("Eje X")
ax[0].set_ylabel("Eje Y")

ax[1].plot(x,y2)
ax[1].set_xlim(0,5)
ax[1].set_ylim(-15,15)
ax[1].set_title("recta baja")
ax[1].set_xlabel("Eje X")
# Out:
# Text(0.5, 0, 'Eje X')

# %% [markdown]
# 6. Crea una lista de coordenadas X: 20, 22, 24, 26, 28
# Crea una lista de coordenadas Y: 5, 15, -5, 20, 5
# Usa un gráfico de barras colocadas en X con alturas Y

# %%
x = [20, 22, 24, 26, 28] # coordenadas x
y = [5, 15, -5, 20, 5] # coordenadas y

plt.bar(x, y); #gráfico de barras

# %% [markdown]
# 7. Crea un gráfico de barras. Pintamos la altura de un grupo de amigos, cada barra representa a una persona. Ana mide 160 cm, Luis mide 180 cm, Pedro mide 175 cm, Sofía mide 190 cm, Carmen mide 170 cm. Las barras serán verdes.
# Consejo: si no vas a tener que manipular especialmente los ejes, es más sencillo dejarlos dentro de la figura.

# %%
nombres = ["Ana", "Luis", "Pedro", "Sofía", "Carmen"] # lista de nombres
alturas = [160, 180, 175, 190, 170] # lista de alturas

plt.bar(nombres, alturas, color="#57c066"); # se puede sacar un selector de color poniendo "#ffffff"

# %% [markdown]
# 8. Cambia el tamaño de la figura a (3,5)

# %%
nombres = ["Ana", "Luis", "Pedro", "Sofía", "Carmen"]
alturas = [160, 180, 175, 190, 170]

plt.figure(figsize=(3, 5))  # introduzco esta línea, que cambia el tamaño de la figura a 3, 5
plt.bar(nombres, alturas, color="#dc2d2d");

# %% [markdown]
# 9. Basándote en el gráfico anterior, borra la escala del eje Y (ya aparece en la altura)
# Pista: cuando plt.yticks() recibe una lista vacía no pinta el eje Y

# %%
nombres = ["Ana", "Luis", "Pedro", "Sofía", "Carmen"]
alturas = [160, 180, 175, 190, 170]

plt.figure(figsize=(3, 5))  # introduzco esta línea, que cambia el tamaño de la figura a 3, 5
plt.yticks([]) # introduzco la línea que sugiere el enunciado, pero con [] dentro del método
plt.bar(nombres, alturas, color="#5e9cde");

# %% [markdown]
# 10. Prueba a hacer el gráfico con las barras en horizontal.

# %%
nombres = ["Ana", "Luis", "Pedro", "Sofía", "Carmen"]
alturas = [160, 180, 175, 190, 170]

plt.figure(figsize=(3, 5))  # introduzco esta línea, que cambia el tamaño de la figura a 3, 5
plt.barh(nombres, alturas, color="#23efab"); # solamente hay que utilizar .barh(), en lugar de .bar()

# %% [markdown]
# 11. Prueba a invertir los ejes con ax.invert_axis()
# Necesitarás tener los ejes disponibles fuera de la figura

# %%
nombres = ["Ana", "Luis", "Pedro", "Sofía", "Carmen"]
alturas = [160, 180, 175, 190, 170]

plt.style.use('classic')
fig, ax = plt.subplots(figsize=(3, 5))  # Crear figura y ejes
ax.barh(nombres, alturas, color="#ffc219")  # Crear gráfico de barras horizontales

ax.invert_xaxis()  # Invierto el eje y (con lo que los nombres quedan al revés)

# %% [markdown]
# 12. En el último gráfico, cambia el estilo a 'dark_background'

# %%
plt.style.use('dark_background')  # utilizo el estilo dark_background

nombres = ["Ana", "Luis", "Pedro", "Sofía", "Carmen"]
alturas = [160, 180, 175, 190, 170]

fig, ax = plt.subplots(figsize=(3, 5))
ax.barh(nombres, alturas, color="#8f3232")

ax.invert_xaxis()

# %% [markdown]
# 13. Vamos a introducir pandas. Crea un DataFrame con las columnas "Year" de valores 2015, 2016, 2017, 2018, 2019 y la columna "Sold_items_A" de valores 1000, 3500, 4000, 5500, 7000

# %%
df = pd.DataFrame({"Year": [2015, 2016, 2017, 2018, 2019], "Sold_items_A": [1000, 3500, 4000, 5500, 7000]}) # creo un dataframe con un diccionario

df
# Out:
#    Year  Sold_items_A
# 0  2015          1000
# 1  2016          3500
# 2  2017          4000
# 3  2018          5500
# 4  2019          7000

# %% [markdown]
# 14. Ahora pintamos un gráfico de línea con las ventas respecto al año. Pon un título y etiquetas en los ejes.
# Cambia el estilo a 'seaborn-white'. La línea debe ser con rayas y verde.

# %%
print(plt.style.available) # estoy buscando si el estilo seaborn-white existe
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8')  # utilizo el estilo seaborn-v0_8, ya que seaborn-white me daba error

fig, ax = plt.subplots() # creo la figura y los ejes


ax.plot(df["Year"], df["Sold_items_A"], linestyle='--', color='green') # el gráfico incluye las dos columnas, el estilo de rayas, verde

ax.set_title("Ventas anuales") # titulo el gráfico
ax.set_xlabel("Año") # etiqueta eje x
ax.set_ylabel("Unidades vendidas"); # etiqueta eje y

# %% [markdown]
# 15. Otro departamento B ha vendido en esos años 2000, 3100, 5000, 4000, 6000 unidades. Incluye esa columna en el DataFrame y pinta en la misma gráfica las dos líneas. B es una línea punteada y roja. Muestra una leyenda abajo a la derecha.

# %%
df["Sold_items_B"] = [2000, 3100, 5000, 4000, 6000] # añado la columna

df
# Out:
#    Year  Sold_items_A  Sold_items_B
# 0  2015          1000          2000
# 1  2016          3500          3100
# 2  2017          4000          5000
# 3  2018          5500          4000
# 4  2019          7000          6000

# %%
plt.style.use('seaborn-v0_8')  

fig, ax = plt.subplots() # creo la figura y los ejes

ax.plot(df["Year"], df["Sold_items_A"], linestyle='--', color='green') # el gráfico incluye las dos columnas, el estilo de rayas y color verde
ax.plot(df["Year"], df["Sold_items_B"], linestyle=':', color='red') # el gráfico incluye las dos columnas, el estilo de puntos y color rojo

ax.set_title("Ventas anuales") # título gráfico
ax.set_xlabel("Año") # título eje x
ax.set_ylabel("Unidades vendidas"); # título eje y

# %% [markdown]
# 16. Haz un scatter del departamento A usando __solo el DataFrame__.
# Pista: el propio DataFrame tiene un método plot.
# df.plot('columna X', 'columna Y', 'kind' = 'scatter)

# %%
df.plot('Year', 'Sold_items_A', kind='scatter'); # utilizo el método sugerido en el enunciado

# %% [markdown]
# 17. Prueba a cambiar kind a 'pie'

# %%
df.plot('Year', 'Sold_items_A', kind='pie'); # cambio a pie, pero no está bien representado

# %%
# lo lógico sería utilizar pie con el eje y con los articulos vendidos y las etiquetas con el año

df.plot(kind='pie', y='Sold_items_A', labels=df['Year'])
# Out:
# <Axes: >

# %% [markdown]
# 18. Prueba a quitar la leyenda incluyendo legend igual a False, añade labels y quita la etiqueta en Y

# %%
# incluyo legend=False, añado los años como etiquetas y quito la etiqueta y

df.plot(kind='pie', y='Sold_items_A', labels=df['Year'], legend=False, ylabel='')
# Out:
# <Axes: >

# %% [markdown]
# 19. Vamos a pintar un histograma de unas alturas generadas aleatoriamente. Crea 300 alturas entre 150 y 190 cm.

# %% [markdown]
# Pista: https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.plot.html

# %% [markdown]
# Se puede hacer a través de un dataframe con una columna de alturas aleatorias:

# %%
alturas = np.random.uniform(150, 190, 300) # genero alturas aleatorias

df_alturas = pd.DataFrame(alturas, columns=['Altura']) # creo el dataframe

df_alturas # muestro el dataframe
# Out:
#          Altura
# 0    156.996448
# 1    157.746609
# 2    188.861457
# 3    159.126229
# 4    179.814058
# ..          ...
# 295  151.423709
# 296  184.554375
# 297  184.265817
# 298  157.169422
# 299  159.216211
#
# [300 rows x 1 columns]

# %%
df_alturas.hist(bins=20); # muestro el histograma con agrupaciones de 20

# %% [markdown]
# También se podría hacer directamente con el array aleatorio de alturas:

# %%
alturas = np.random.uniform(150, 190, 300) # genero alturas aleatorias

plt.hist(alturas, bins=30); # muestro el histograma a partir del array de alturas, con bins de 30 elementos
