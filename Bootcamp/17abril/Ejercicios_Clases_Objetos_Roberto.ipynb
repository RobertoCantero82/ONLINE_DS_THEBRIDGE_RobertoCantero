# %% [markdown]
# ![imagen](./img/ejercicios.png)
#
# # Ejercicios Clases y Objetos

# %% [markdown]
# ## Ejercicio 1
# Somos una empresa que tiene varias tiendas de electrodomésticos. Necesitamos un programa para manejar las tiendas, ver las ventas que han tenido, cuántos empleados hay, etc... Para ello vamos a modelizar la tienda en una clase, que tendrá las siguientes características:
# * Nombre clase: "Tienda"
# * Atributos comunes:
#     * Tipo: "Electrodomésticos"
#     * Abierta: True
# * Atributos propios de cada tienda:
#     * Nombre - String
#     * Dirección - String
#     * Número de empleados - int
#     * Ventas últimos 3 meses - Lista de 3 numeros
# * Método para calcular las ventas de todos los meses, que devuelva un número con todas las ventas.
# * Método que calcula la media de ventas de los últimos meses, por empleado
# * Método que devuelve en un string el nombre de la tienda, junto con su dirección.
# * Método que obtiene las ventas del último mes.
# * Método para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda. Siendo X el parámetro de entrada. Si X es menor de 1000, las ventas de los ultimos 3 meses hubiesen sido de (1.2 x ventas), si es mayor o igual de 1000, las ventas hubiesen sido de (1.5 x venta). El método reescribe el atributo de ventas en los últimos 3 meses, y además devuelve las ventas con el aumento.
#
# Se pide:
# 1. Implementar la clase "Tienda"
# 2. Crear tres tiendas con datos inventados
# 3. Comprueba en al menos una de ellas, todo lo implementado en la clase tienda (sus atributos, media de ventas, ventas/empleado...)
# 3. Calcular las ventas del último mes de todas las tiendas. Para ello usa el bucle `for`
# 4. Imprime por pantalla los nombres de las tiendas cuya dirección lleve el string "Avenida"
# 5. Seguro que ya has hecho este apartado... Documenta la clase :)

# %%
class Tienda:
    '''
    Esta es la clase Tienda, que representa a las tiendas del grupo ElectroBridge
    Tiene como atributos tipo, que por defecto es "Electrodomésticos", abierto, que por defecto es True,
    nombre, dirección, número de empleados y ventas de los tres últimos meses
    '''

    tipo = "Electrodomésticos"
    abierta = True
    
    def __init__(self, nombre, direccion, numero_empleados, ventas_3meses):
        self.nombre = nombre
        self.direccion = direccion
        self.numero_empleados = numero_empleados
        self.ventas_3meses = ventas_3meses
    
    def total_ventas(self):
        '''
        Esta es la función para calcular el total de ventas de los últimos tres meses
        '''
        return sum(self.ventas_3meses)
       
    
    def media_ventas_empleado(self):
        '''
        Esta es la función para calcular la media de ventas de los empleados en los tres últimos meses
        '''
        return self.total_ventas() / self.numero_empleados
        

    def nombre_direccion(self):
        '''
        Esta es la función para devolver nombre y dirección de una tienda
        '''
        return f"Esta tienda es {self.nombre} y está en {self.direccion}"
            


     
    def ventas_ultimo_mes(self):
        '''
        Esta es la función para devolver las ventas del último mes
        '''  
        return self.ventas_3meses[2]
         

    def proyeccion_ventas(self, x):
        '''
        Esta es la función para calcular una proyección de ventas dependiendo de las acciones de marketing. Si
        son de menos de 1000 euros, las ventas serán un 20% mayores. Si son más de 1000 o igual, el incremento será del 50%.
        '''
        if x < 1000:
            return self.total_ventas() * 1.2
        elif x >= 1000:
            return self.total_ventas() * 1.5

# %%
print(tienda1.total_ventas())
print(tienda2.media_ventas_empleado())
print(tienda3.nombre_direccion())
print(tienda1.ventas_ultimo_mes())
print(tienda3.proyeccion_ventas(1500))
# Out:
# 125000 euros
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 2
#       1 print(tienda1.total_ventas())
# ----> 2 print(tienda2.media_ventas_empleado())
#       3 print(tienda3.nombre_direccion())
#       4 print(tienda1.ventas_ultimo_mes())
#       5 print(tienda3.proyeccion_ventas(1500))
#
# Cell In[2], line 15, in Tienda.media_ventas_empleado(self)
#      14     def media_ventas_empleado(self):
# ---> 15         return self.total_ventas // self.numero_empleados
#
# TypeError: unsupported operand type(s) for //: 'method' and 'int'

# %%
tienda1 = Tienda("ElectroBridge", "Avenida Gasteiz, 340", 20, [40000, 45000, 40000])
tienda2 = Tienda("ElectroBridge Salburua", "Avenida 8 de Marzo , 30", 10, [30000, 25000, 50000])
tienda3 = Tienda("ElectroBridge Goikolarra", "Calle Ocariz, 3", 5, [10000, 5000, 15000])

# %%
print(tienda3.__dict__)
# Out:
# {'nombre': 'ElectroBridge Goikolarra', 'direccion': 'Calle Ocariz, 3', 'numero_empleados': 5, 'ventas_3meses': [10000, 5000, 15000]}

# %%
suma = 0
for i in grupo_electrobridge:
    suma = suma +i.ventas_3meses[2]
print("El total de ventas de todas las tiendas el último mes es de", suma, "euros.")
# Out:
# El total de ventas de todas las tiendas el último mes es de 105000 euros.

# %%
tiendas = [tienda1, tienda2, tienda3]
for i in tiendas:
    if "Avenida" in i.direccion:
        print(i.nombre)
# Out:
# ElectroBridge
# ElectroBridge Salburua

# %%
help(Tienda)
# Out:
# Help on class Tienda in module __main__:
#
# class Tienda(builtins.object)
#  |  Tienda(nombre, direccion, numero_empleados, ventas_3meses)
#  |
#  |  Esta es la clase Tienda, que representa a las tiendas del grupo ElectroBridge
#  |  Tiene como atributos tipo, que por defecto es "Electrodomésticos", abierto, que por defecto es True,
#  |  nombre, dirección, número de empleados y ventas de los tres últimos meses
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, nombre, direccion, numero_empleados, ventas_3meses)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  media_ventas_empleado(self)
#  |      Esta es la función para calcular la media de ventas de los empleados en los tres últimos meses
#  |
#  |  nombre_direccion(self)
#  |      Esta es la función para devolver nombre y dirección de una tienda
#  |
#  |  proyeccion_ventas(self, x)
#  |      Esta es la función para calcular una proyección de ventas dependiendo de las acciones de marketing. Si
#  |      son de menos de 1000 euros, las ventas serán un 20% mayores. Si son más de 1000 o igual, el incremento será del 50%.
#  |
#  |  total_ventas(self)
#  |      Esta es la función para calcular el total de ventas de los últimos tres meses
#  |
#  |  ventas_ultimo_mes(self)
#  |      Esta es la función para devolver las ventas del último mes
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  abierta = True
#  |
#  |  tipo = 'Electrodomésticos'

# %% [markdown]
# ## Ejercicio 2
# En este ejercicio vamos a implementar una clase *Perro* en Python. La clase tiene las siguientes características:
# * Cosas que sabemos seguro que tiene un perro
#     * Tiene 4 patas
#     * 2 orejas
#     * 2 ojos
#     * Una velocidad de 0. Por defecto, el perro está parado
# * Cuando se inicialice:
#     * El perro será de una determinada raza
#     * Por defecto tendrá pelo "Marrón", a no ser que se diga lo contrario.
#     * Por defecto no tendrá dueño, a no ser que se diga lo contrario.
#
# * Dispondrá también de un método llamado andar, que tiene un argumento de entrada (aumento_velocidad). Este valor se le sumará a la velocidad que ya llevaba el perro.
# * Necesita otro método (parar), donde pondremos la velocidad a 0.
# * Otro método llamado "ladrar", que tendrá un argumento de entrada, y la salida será el siguiente string: "GUAU!" + el argumento de entrada.
#
#
# Se pide:
# * Implementa la clase *Perro*
# * Crea un objeto de tipo *Perro*, sin dueño
# * Comprueba que están bien todos sus atributos
# * Prueba que ande, y comprueba su velocidad
# * Páralo
# * Documenta la clase *Perro*
