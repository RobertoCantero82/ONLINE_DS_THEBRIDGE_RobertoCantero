# %% [markdown]
# # Pasos a dar para el proyecto

# %% [markdown]
# 1- Diseño (ER, Logico)
#
# 2- Desplegar base de datos en Render
#
# 3- Crear tablas, PK y FK
#
# 4- Insertar (a mano o a través de Pandas)
#
# 5- Consultas
