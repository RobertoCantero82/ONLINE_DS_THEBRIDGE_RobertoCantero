# %% [markdown]
# # Conexión a una base de datos PostGresSql

# %%
import psycopg2
import pandas as pd

# %% [markdown]
# hosting en Render es External Database URL.
# Pero no se copia directamente, sino que de la copia original "postgresql://roberto:TLH3dLYlrEUe5AYGTzl1zZILE0ke6mfQ@dpg-d86od7btqb8s73fpch2g-a.oregon-postgres.render.com/bbdd_proyecto_q7rl", se queda solo "dpg-d86od7btqb8s73fpch2g-a.oregon-postgres.render.com".
# **Se usa solo desde la @ hasta el render.com**

# %%
hosting = "dpg-d86od7btqb8s73fpch2g-a.oregon-postgres.render.com" 
puerto = "5432"
nombre_db = "bbdd_proyecto_q7rl"
usuario = "roberto"
pswd = "TLH3dLYlrEUe5AYGTzl1zZILE0ke6mfQ"

# %%
conn = psycopg2.connect(
        host = hosting,
        port = puerto,
        dbname = nombre_db,
        user = usuario,
        password = pswd
)

# %%
cursor = conn.cursor()

# %%
def sql_query(query):   # SELECT * FROM TRACKS

    # Ejecuta la query
    cursor.execute(query)

    # Almacena los datos de la query 
    ans = cursor.fetchall()

    # Obtenemos los nombres de las columnas de la tabla
    names = [description[0] for description in cursor.description]

    return pd.DataFrame(ans,columns=names)
