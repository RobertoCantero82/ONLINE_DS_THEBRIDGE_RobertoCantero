# %% [markdown]
# ## Colecciones Python: Sets

# %% [markdown]
# ### Contenidos

# %% [markdown]
# * [Introducción](#Introducción)

# %% [markdown]
# ### Introducción
# [al indice](#Contenidos)
#
# Otra colección *bulit-in* de Python, compuesta por un conjunto de *valores*. Muy parecidos a las listas. Tienen las siguientes características:
# * **Mutables**: podemos modificarlos una vez se hayan creado
# * **No ordenado**
# * **Elementos unicos**: se compone de un conjunto de valores únicas
#
# **¿Cuándo usar sets?** Cuando estemos buscando unicidad en nuestros datos y no nos importe el orden.
#
# Te dejo por aquí [la documentación](https://docs.python.org/2/library/sets.html) para realizar consultas sobre los sets
#
# Si sintaxis es:
# >```Python
# > mi_set = {elemento1, elemento2, elemento3}
# >```
#
# Tiene una sintaxis muy parecida a la de las listas, pero en este caso no se utilizan los `{}`.

# %%
colores = {"azul", "rojo", "verde", "naranja", "azul", "verde"}
print(colores)
print(type(colores))
print(len(colores))
# Out:
# {'naranja', 'azul', 'verde', 'rojo'}
# <class 'set'>
# 4

# %% [markdown]
# Los elementos del set son unicos, por lo que si en la declaración, o posteriormente añadiendo elementos hubiese algún duplicado, el set lo ignoraría. Es más, cuando aplicas el `len`, muestra la cantidad de valores únicos que tiene.

# %%
# Añadir valores

colores.add("Magenta")
print(colores)

# Añadir lista a set

colores.update(["celeste", "burdeos", "naranja"]) # No añade naranja porque los sets ignoran los duplicados
print(colores)

# Eliminar valores

colores.remove("naranja")
print(colores)

# Iterar en sets

for color in colores:
    print(color)
# Out:
# {'burdeos', 'verde', 'Magenta', 'celeste', 'rojo', 'azul'}
# {'burdeos', 'verde', 'Magenta', 'celeste', 'rojo', 'naranja', 'azul'}
# {'burdeos', 'verde', 'Magenta', 'celeste', 'rojo', 'azul'}
# burdeos
# verde
# Magenta
# celeste
# rojo
# azul

# %% [markdown]
# Para comprobar si dos sets tienen los mismos elementos

# %%
set1 = {1,2,4,4,2,1,2,1}
set2 = {2,1,4}
set1 == set2
# Out:
# True

# %%
# Quitar duplicados de listas

lista_con = [100, 10, 23, 23, 15, 32, 45, 10, 100, 23]

print(lista_con, type(lista_con)) # Originalmente es una lista con duplicados

print(set(lista_con)) # Convertimos de lista a set

print(list(set(lista_con))) # Convertimos el set en lista, pero ya sin duplicados

lista_con = list(set(lista_con)) # Asignamos la conversión a lista_con

print(lista_con, type(lista_con)) # Acabamos con la misma lista, pero sin duplicados
# Out:
# [100, 10, 23, 23, 15, 32, 45, 10, 100, 23] <class 'list'>
# {32, 100, 10, 45, 15, 23}
# [32, 100, 10, 45, 15, 23]
# [32, 100, 10, 45, 15, 23] <class 'list'>
